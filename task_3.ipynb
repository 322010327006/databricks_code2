# %%
def add(a,b):
    return a+b
res = add(1,2)
print(res)

# %%
def sqr(a):
    return a*a
res = sqr(2)
print(res)

# %%
def mul(a,b):
    return a*b
res = mul(2,3)
print(res)

# %%
def cub(a):
    return a*a*a
res = cub(3)
print(res)
