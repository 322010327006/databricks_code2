# %%
print("hello")

# %%
for i in range(10):
    print(i)

# %%
for i in range(20):
    if i % 2 == 0:
        print("It is even number")
    else:
        print("It is odd number")

# %%
a = 'wow'
if a == a[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")

# %%
print("i have made the changes")
