# %%
# %sql
select * from customers_100

# %%
# %sql
select * from customers_100
where Country = "Netherlands"

# %%
# %sql
select `Customer Id`, count(*) as count
from customers_100
group by `Customer Id`

# %%
# %sql
select * from customers_100
where `Subscription Date` >= '2019-01-01'
LIMIT 10

# %%
# %sql
select * from workspace.default.big_mart_sales
