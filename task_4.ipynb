# %%
# %sql
select * from customers_100

# %%
# %sql
select * from customers_100
where 'First Name' like '%a%'

# %%
# %sql
select * from customers_100
where 'Last Name' like '%a%'

# %%
# %sql
select * from customers_100
where 'First Name' like '%a%' and `Last Name` like '%a%'

# %%
print("hello")
